# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('day2_input.csv')

# %%
# Out:
#                                                value
# 0  5542145-5582046,243-401,884211-917063,1174-166...
